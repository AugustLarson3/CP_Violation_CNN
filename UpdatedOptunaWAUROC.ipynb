# %%
import uproot
import torch
import numpy as np
import mplhep
from matplotlib import pyplot as plt
import torch.nn as nn
import xgboost as xgb
import torch.optim as optim
import sklearn.datasets
import sklearn.metrics
from sklearn.metrics import roc_curve, auc, accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import optuna
from xgboost import XGBClassifier

# %%
file = uproot.open('/Users/augielarson/Desktop/LHCb_CERN_Datasets_Research/Gen_DKKPi_1.root')
tree = file['fitTree']
data_df = tree.arrays(library='pd')

# %%
data_df.head()
# Out:
#    charge  genSig  genqqbar  iEvtWithinExpt  iExpt  cosHel12  cosHel13  \
# 0      -1       1         0               0      0 -0.600779 -0.021703
# 1      -1       1         0               1      0 -0.256318  0.576692
# 2      -1       1         0               2      0 -0.616962  0.612876
# 3      -1       1         0               3      0  0.924468  0.827218
# 4      -1       1         0               4      0 -0.268246  0.781068
#
#    cosHel23  efficiency  evtWeight       m12     m12Sq       m13     m13Sq  \
# 0 -0.618265         1.0        1.0  0.829710  0.688418  1.616485  2.613025
# 1  0.517862         1.0        1.0  1.238359  1.533533  1.264775  1.599655
# 2  0.245549         1.0        1.0  1.139805  1.299155  1.421750  2.021373
# 3  0.972939         1.0        1.0  1.314340  1.727489  1.018129  1.036586
# 4  0.778652         1.0        1.0  1.314281  1.727334  1.199678  1.439226
#
#         m23     m23Sq    mPrime   thPrime
# 0  0.837294  0.701062  0.656096  0.705143
# 1  0.932372  0.869317  0.283286  0.582509
# 2  0.825819  0.681977  0.381394  0.711637
# 3  1.112848  1.238430  0.186025  0.124510
# 4  0.914300  0.835945  0.186117  0.586444

# %%
variables = [
    'mPrime', 'thPrime', 'charge', 'genSig', 'genqqbar', 'iEvtWithinExpt', 'iExpt', 
    'cosHel12', 'cosHel13', 'cosHel23', 'efficiency', 'evtWeight', 'm12', 'm12Sq', 
    'm13', 'm13Sq', 'm23', 'm23Sq'
]

# %%
# Array Extraction and Storage
arrays = [tree[var].array(library='np') for var in variables]

# Stacking Input Arrays (Charge Agnostic)
input_data_arr = np.stack(arrays[:-1], axis=1)
charge_arr = arrays[2]
prediction_metric = np.where(charge_arr > 0, 1, 0)


# Split; Training (70%), Validation (15%), Test (15%)
x_train, x_temp, y_train, y_temp = train_test_split(input_data_arr, prediction_metric, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %%
# Objective Func
num_epochs = 30
def objective(trial):
    # Hyperparams Suggestions
    learning_rate = trial.suggest_float("learning_rate", 1e-5, 1e-1, log=True)
    max_depth = trial.suggest_int("max_depth", 2, 10, step=2)
    n_estimators = trial.suggest_int("n_estimators", 100, 300, step=100)
    gamma = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
    min_child_weight = trial.suggest_int("min_child_weight", 2, 10)
    max_delta_step = trial.suggest_int("max_delta_step", 0, 10)
    subsample = trial.suggest_float("subsample", 0.2, 1.0)
    
    # XGB Hyperparams
    model = XGBClassifier(
        objective='binary:logistic',
        learning_rate=learning_rate,
        n_estimators=n_estimators,
        max_depth=max_depth,
        gamma=gamma,
        min_child_weight=min_child_weight,
        max_delta_step=max_delta_step,
        subsample=subsample,
        seed=42,
        use_label_encoder=False,
        eval_metric='logloss'  # THis avoids the wanring for label encoding
    )

    # Train Model
    model.fit(x_train, y_train, eval_set=[(x_val, y_val)], early_stopping_rounds=10, verbose=False)

    # Valid Pred Set
    y_pred = model.predict(x_val)

    # Accuracy
    accuracy = accuracy_score(y_val, y_pred)

    return accuracy

# Running Optuna
if __name__ == "__main__":
    # Creating a study to maximize accuracy
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=1000, timeout=600)

    # Output Results
    print("Number of finished trials: ", len(study.trials))
    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))
    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))

    # Retrieve best Hyperparams
    best_params = trial.params

    # Train w/ best Hyperparams
    final_model = XGBClassifier(
        objective='binary:logistic',
        learning_rate=best_params['learning_rate'],
        n_estimators=best_params['n_estimators'],
        max_depth=best_params['max_depth'],
        gamma=best_params['gamma'],
        min_child_weight=best_params['min_child_weight'],
        max_delta_step=best_params['max_delta_step'],
        subsample=best_params['subsample'],
        seed=42,
        use_label_encoder=False,
        eval_metric='logloss'
    )

    # Final Training
    final_model.fit(x_train, y_train, eval_set=[(x_val, y_val)], early_stopping_rounds=10, verbose=False)

    # Preds on Test
    y_test_pred = final_model.predict(x_test)

    # ROC and AUROC for Test
    fpr, tpr, _ = roc_curve(y_test, y_test_pred)
    roc_auc = auc(fpr, tpr)

    # Plotting ROC
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

    # New Data Point Preds
    X_new = np.random.randn(1, x_train.shape[1])
    output = final_model.predict(X_new)
    print("Prediction:", output[0])
# Out:
# [I 2024-10-06 23:28:10,974] A new study created in memory with name: no-name-7ff93f71-8972-4ceb-9948-9c0b5b7f5a6f
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:12,492] Trial 0 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.00036809302513860534, 'max_depth': 4, 'n_estimators': 300, 'gamma': 5.0910969153166114e-08, 'min_child_weight': 5, 'max_delta_step': 5, 'subsample': 0.6909219590169432}. Best is trial 0 with value: 0.6341333333333333.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:13,462] Trial 1 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 4.768785558590724e-05, 'max_depth': 2, 'n_estimators': 200, 'gamma': 0.00018710393192242566, 'min_child_weight': 2, 'max_delta_step': 10, 'subsample': 0.710695144217468}. Best is trial 0 with value: 0.6341333333333333.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:14,421] Trial 2 finished with value: 1.0 and parameters: {'learning_rate': 0.002221943080608557, 'max_depth': 2, 'n_estimators': 200, 'gamma': 0.24648397431573266, 'min_child_weight': 8, 'max_delta_step': 0, 'subsample': 0.5285793038045091}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:15,767] Trial 3 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.0003035796755560132, 'max_depth': 10, 'n_estimators': 300, 'gamma': 0.2726520259222235, 'min_child_weight': 5, 'max_delta_step': 6, 'subsample': 0.6408511679742799}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:16,719] Trial 4 finished with value: 1.0 and parameters: {'learning_rate': 0.023734541241630103, 'max_depth': 6, 'n_estimators': 200, 'gamma': 6.514719119102677e-08, 'min_child_weight': 6, 'max_delta_step': 8, 'subsample': 0.6517251905198885}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:17,249] Trial 5 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 2.2325309090276954e-05, 'max_depth': 6, 'n_estimators': 100, 'gamma': 0.0002983364979329268, 'min_child_weight': 10, 'max_delta_step': 6, 'subsample': 0.9205706714795079}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:18,738] Trial 6 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.0005201536827760719, 'max_depth': 6, 'n_estimators': 300, 'gamma': 2.2663964140514525e-06, 'min_child_weight': 3, 'max_delta_step': 4, 'subsample': 0.5811623135025459}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:19,374] Trial 7 finished with value: 1.0 and parameters: {'learning_rate': 0.07764752932290797, 'max_depth': 4, 'n_estimators': 300, 'gamma': 0.02125759299482281, 'min_child_weight': 3, 'max_delta_step': 4, 'subsample': 0.5294167402024751}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:20,701] Trial 8 finished with value: 1.0 and parameters: {'learning_rate': 0.004211850921201547, 'max_depth': 6, 'n_estimators': 300, 'gamma': 5.799575070105795e-06, 'min_child_weight': 3, 'max_delta_step': 0, 'subsample': 0.44494652825982084}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:22,088] Trial 9 finished with value: 1.0 and parameters: {'learning_rate': 0.0025540404064873404, 'max_depth': 2, 'n_estimators': 300, 'gamma': 7.398069513119615e-05, 'min_child_weight': 4, 'max_delta_step': 1, 'subsample': 0.6293180814847233}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:22,624] Trial 10 finished with value: 1.0 and parameters: {'learning_rate': 0.02062637582721182, 'max_depth': 10, 'n_estimators': 100, 'gamma': 0.826070400282028, 'min_child_weight': 9, 'max_delta_step': 2, 'subsample': 0.21116125120315987}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:23,662] Trial 11 finished with value: 1.0 and parameters: {'learning_rate': 0.013416220552113844, 'max_depth': 8, 'n_estimators': 200, 'gamma': 1.4599516589317508e-08, 'min_child_weight': 7, 'max_delta_step': 9, 'subsample': 0.337838415314894}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:24,302] Trial 12 finished with value: 1.0 and parameters: {'learning_rate': 0.07599779743761256, 'max_depth': 4, 'n_estimators': 200, 'gamma': 0.004994467376502303, 'min_child_weight': 7, 'max_delta_step': 8, 'subsample': 0.8488017526377954}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:25,305] Trial 13 finished with value: 1.0 and parameters: {'learning_rate': 0.00863992636387207, 'max_depth': 8, 'n_estimators': 200, 'gamma': 4.4231928162677796e-07, 'min_child_weight': 8, 'max_delta_step': 8, 'subsample': 0.7765416425561871}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:25,980] Trial 14 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.0014834151696631274, 'max_depth': 2, 'n_estimators': 100, 'gamma': 0.006701426341978106, 'min_child_weight': 6, 'max_delta_step': 2, 'subsample': 0.4511049482237841}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:26,996] Trial 15 finished with value: 1.0 and parameters: {'learning_rate': 0.027607888262610576, 'max_depth': 8, 'n_estimators': 200, 'gamma': 2.068527429196531e-05, 'min_child_weight': 8, 'max_delta_step': 7, 'subsample': 0.4758135464553573}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:27,938] Trial 16 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.00015178252197691361, 'max_depth': 4, 'n_estimators': 200, 'gamma': 4.1488289163885716e-07, 'min_child_weight': 10, 'max_delta_step': 10, 'subsample': 0.37860949497749363}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:28,439] Trial 17 finished with value: 1.0 and parameters: {'learning_rate': 0.0037247547009243848, 'max_depth': 2, 'n_estimators': 100, 'gamma': 0.06293054501617999, 'min_child_weight': 6, 'max_delta_step': 3, 'subsample': 0.9876719145827338}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:29,378] Trial 18 finished with value: 1.0 and parameters: {'learning_rate': 0.0013102096790920156, 'max_depth': 8, 'n_estimators': 200, 'gamma': 0.000880603992004696, 'min_child_weight': 8, 'max_delta_step': 7, 'subsample': 0.7818624478883947}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:30,371] Trial 19 finished with value: 1.0 and parameters: {'learning_rate': 0.0075325122949745195, 'max_depth': 4, 'n_estimators': 200, 'gamma': 2.395026045945878e-07, 'min_child_weight': 7, 'max_delta_step': 0, 'subsample': 0.2710445450801402}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:30,893] Trial 20 finished with value: 1.0 and parameters: {'learning_rate': 0.04100103236084601, 'max_depth': 6, 'n_estimators': 100, 'gamma': 0.0020826190775382553, 'min_child_weight': 9, 'max_delta_step': 5, 'subsample': 0.544009020458464}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:31,517] Trial 21 finished with value: 1.0 and parameters: {'learning_rate': 0.09680530421629388, 'max_depth': 4, 'n_estimators': 200, 'gamma': 0.038125237190689575, 'min_child_weight': 2, 'max_delta_step': 3, 'subsample': 0.5375731746974832}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:32,364] Trial 22 finished with value: 1.0 and parameters: {'learning_rate': 0.05024708623903878, 'max_depth': 4, 'n_estimators': 300, 'gamma': 0.047062277560339705, 'min_child_weight': 5, 'max_delta_step': 4, 'subsample': 0.49134779537913703}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:33,421] Trial 23 finished with value: 1.0 and parameters: {'learning_rate': 0.02033778284255456, 'max_depth': 2, 'n_estimators': 200, 'gamma': 0.9920617893545545, 'min_child_weight': 4, 'max_delta_step': 1, 'subsample': 0.36869354928018794}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:34,819] Trial 24 finished with value: 1.0 and parameters: {'learning_rate': 0.010040314920070167, 'max_depth': 6, 'n_estimators': 300, 'gamma': 0.018933580378122046, 'min_child_weight': 4, 'max_delta_step': 6, 'subsample': 0.691082366909676}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:35,755] Trial 25 finished with value: 1.0 and parameters: {'learning_rate': 0.04299327707890789, 'max_depth': 4, 'n_estimators': 200, 'gamma': 0.16989700222089305, 'min_child_weight': 9, 'max_delta_step': 4, 'subsample': 0.5783883835214264}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:36,669] Trial 26 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.00012065465310471309, 'max_depth': 2, 'n_estimators': 200, 'gamma': 3.739755021426279e-05, 'min_child_weight': 3, 'max_delta_step': 9, 'subsample': 0.7482824756251018}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:37,279] Trial 27 finished with value: 1.0 and parameters: {'learning_rate': 0.09633561377896488, 'max_depth': 6, 'n_estimators': 300, 'gamma': 0.16185569766403737, 'min_child_weight': 6, 'max_delta_step': 2, 'subsample': 0.6269408244906526}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:38,342] Trial 28 finished with value: 1.0 and parameters: {'learning_rate': 0.004973396157479205, 'max_depth': 4, 'n_estimators': 200, 'gamma': 0.007796947923530577, 'min_child_weight': 7, 'max_delta_step': 7, 'subsample': 0.5325334324004224}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:39,743] Trial 29 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.0004619569912027896, 'max_depth': 2, 'n_estimators': 300, 'gamma': 6.680380121779374e-08, 'min_child_weight': 5, 'max_delta_step': 3, 'subsample': 0.42108704384581236}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:41,146] Trial 30 finished with value: 1.0 and parameters: {'learning_rate': 0.0020020782817228864, 'max_depth': 4, 'n_estimators': 300, 'gamma': 0.0007340266532725742, 'min_child_weight': 6, 'max_delta_step': 5, 'subsample': 0.6770700746236425}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:42,572] Trial 31 finished with value: 1.0 and parameters: {'learning_rate': 0.004759942321515803, 'max_depth': 6, 'n_estimators': 300, 'gamma': 6.979451761882452e-06, 'min_child_weight': 3, 'max_delta_step': 0, 'subsample': 0.415291088267325}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:43,944] Trial 32 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.0009063402112869888, 'max_depth': 6, 'n_estimators': 300, 'gamma': 1.4937474250406425e-06, 'min_child_weight': 2, 'max_delta_step': 1, 'subsample': 0.4896392458234022}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:45,354] Trial 33 finished with value: 1.0 and parameters: {'learning_rate': 0.0007714390082063733, 'max_depth': 6, 'n_estimators': 300, 'gamma': 1.1219614739773056e-08, 'min_child_weight': 4, 'max_delta_step': 0, 'subsample': 0.5831067669764273}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:46,784] Trial 34 finished with value: 1.0 and parameters: {'learning_rate': 0.013446757534083665, 'max_depth': 8, 'n_estimators': 300, 'gamma': 5.552442408410269e-06, 'min_child_weight': 3, 'max_delta_step': 1, 'subsample': 0.3300260024433322}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:47,750] Trial 35 finished with value: 1.0 and parameters: {'learning_rate': 0.02817862927383518, 'max_depth': 2, 'n_estimators': 200, 'gamma': 5.076138159431217e-08, 'min_child_weight': 2, 'max_delta_step': 0, 'subsample': 0.535456734609396}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:49,140] Trial 36 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 1.0929911134240179e-05, 'max_depth': 4, 'n_estimators': 300, 'gamma': 0.00010359282096557979, 'min_child_weight': 3, 'max_delta_step': 6, 'subsample': 0.6585627855293121}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:50,217] Trial 37 finished with value: 1.0 and parameters: {'learning_rate': 0.002615579828089452, 'max_depth': 10, 'n_estimators': 200, 'gamma': 0.00036384181858088987, 'min_child_weight': 5, 'max_delta_step': 2, 'subsample': 0.7299698076711592}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:50,996] Trial 38 finished with value: 1.0 and parameters: {'learning_rate': 0.05896970486319985, 'max_depth': 6, 'n_estimators': 300, 'gamma': 1.7091731887689107e-06, 'min_child_weight': 10, 'max_delta_step': 10, 'subsample': 0.622232410870889}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:51,975] Trial 39 finished with value: 1.0 and parameters: {'learning_rate': 0.005933576736118073, 'max_depth': 6, 'n_estimators': 200, 'gamma': 0.2681484725935676, 'min_child_weight': 4, 'max_delta_step': 1, 'subsample': 0.8359965741399082}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:52,527] Trial 40 finished with value: 1.0 and parameters: {'learning_rate': 0.019941691596683436, 'max_depth': 8, 'n_estimators': 100, 'gamma': 8.716741120372057e-08, 'min_child_weight': 2, 'max_delta_step': 8, 'subsample': 0.4560951828863247}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:53,988] Trial 41 finished with value: 1.0 and parameters: {'learning_rate': 0.0031868381473026722, 'max_depth': 2, 'n_estimators': 300, 'gamma': 3.601071099126992e-05, 'min_child_weight': 4, 'max_delta_step': 0, 'subsample': 0.5988383835233491}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:55,444] Trial 42 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.0002286745995758076, 'max_depth': 2, 'n_estimators': 300, 'gamma': 1.0677059503119449e-05, 'min_child_weight': 5, 'max_delta_step': 1, 'subsample': 0.5132359145947594}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:56,793] Trial 43 finished with value: 1.0 and parameters: {'learning_rate': 0.0019177419482654878, 'max_depth': 2, 'n_estimators': 300, 'gamma': 0.00013737355598985725, 'min_child_weight': 3, 'max_delta_step': 2, 'subsample': 0.6472813532915597}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:58,246] Trial 44 finished with value: 1.0 and parameters: {'learning_rate': 0.012551256206380586, 'max_depth': 4, 'n_estimators': 300, 'gamma': 4.757108024285668e-05, 'min_child_weight': 3, 'max_delta_step': 1, 'subsample': 0.5740023377391141}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:28:59,200] Trial 45 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.0006122990894229806, 'max_depth': 2, 'n_estimators': 200, 'gamma': 0.0002901377016455009, 'min_child_weight': 4, 'max_delta_step': 0, 'subsample': 0.4385781424418299}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:00,616] Trial 46 finished with value: 1.0 and parameters: {'learning_rate': 0.0014378287098743229, 'max_depth': 2, 'n_estimators': 300, 'gamma': 8.842907150181392e-07, 'min_child_weight': 7, 'max_delta_step': 5, 'subsample': 0.6949429700357505}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:01,598] Trial 47 finished with value: 1.0 and parameters: {'learning_rate': 0.0033808661089920573, 'max_depth': 4, 'n_estimators': 200, 'gamma': 2.6693112008715356e-08, 'min_child_weight': 8, 'max_delta_step': 4, 'subsample': 0.40407436742656955}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:02,567] Trial 48 finished with value: 1.0 and parameters: {'learning_rate': 0.03328932650923536, 'max_depth': 6, 'n_estimators': 200, 'gamma': 0.4653524278695372, 'min_child_weight': 9, 'max_delta_step': 9, 'subsample': 0.3229035016170184}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:03,506] Trial 49 finished with value: 1.0 and parameters: {'learning_rate': 0.015650621497151147, 'max_depth': 8, 'n_estimators': 200, 'gamma': 1.6201582944837962e-07, 'min_child_weight': 2, 'max_delta_step': 3, 'subsample': 0.6150315320328559}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:04,011] Trial 50 finished with value: 1.0 and parameters: {'learning_rate': 0.007409551682925997, 'max_depth': 4, 'n_estimators': 100, 'gamma': 0.002793445579287348, 'min_child_weight': 6, 'max_delta_step': 0, 'subsample': 0.810083710139708}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:04,527] Trial 51 finished with value: 1.0 and parameters: {'learning_rate': 0.06189961897583231, 'max_depth': 10, 'n_estimators': 100, 'gamma': 0.08467901801342333, 'min_child_weight': 9, 'max_delta_step': 2, 'subsample': 0.24109479475631374}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:05,061] Trial 52 finished with value: 1.0 and parameters: {'learning_rate': 0.021072010736026086, 'max_depth': 10, 'n_estimators': 100, 'gamma': 0.6584226121796634, 'min_child_weight': 8, 'max_delta_step': 1, 'subsample': 0.2047104544527921}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:05,563] Trial 53 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.0025457909888099324, 'max_depth': 8, 'n_estimators': 100, 'gamma': 0.014291388165864291, 'min_child_weight': 10, 'max_delta_step': 2, 'subsample': 0.5603921937552301}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:07,012] Trial 54 finished with value: 1.0 and parameters: {'learning_rate': 0.009384187569339177, 'max_depth': 6, 'n_estimators': 300, 'gamma': 0.09796671226352101, 'min_child_weight': 9, 'max_delta_step': 1, 'subsample': 0.8993305045980283}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:07,549] Trial 55 finished with value: 1.0 and parameters: {'learning_rate': 0.0721492112054012, 'max_depth': 8, 'n_estimators': 100, 'gamma': 0.920263472666942, 'min_child_weight': 9, 'max_delta_step': 3, 'subsample': 0.46009691487277016}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:08,452] Trial 56 finished with value: 1.0 and parameters: {'learning_rate': 0.0397871340748784, 'max_depth': 4, 'n_estimators': 200, 'gamma': 0.36268168047101645, 'min_child_weight': 8, 'max_delta_step': 0, 'subsample': 0.284304347319088}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:10,229] Trial 57 finished with value: 1.0 and parameters: {'learning_rate': 0.0011546021044398743, 'max_depth': 2, 'n_estimators': 300, 'gamma': 3.822232822275641e-06, 'min_child_weight': 7, 'max_delta_step': 4, 'subsample': 0.5191550770152773}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:11,653] Trial 58 finished with value: 1.0 and parameters: {'learning_rate': 0.0061475350241783, 'max_depth': 10, 'n_estimators': 300, 'gamma': 1.4393439280230265e-05, 'min_child_weight': 8, 'max_delta_step': 2, 'subsample': 0.36355157917759484}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:12,685] Trial 59 finished with value: 1.0 and parameters: {'learning_rate': 0.004446463453090452, 'max_depth': 4, 'n_estimators': 200, 'gamma': 0.001410168067121527, 'min_child_weight': 3, 'max_delta_step': 7, 'subsample': 0.6647984655728362}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:14,289] Trial 60 finished with value: 1.0 and parameters: {'learning_rate': 0.022509801537572365, 'max_depth': 6, 'n_estimators': 300, 'gamma': 0.020420228920546322, 'min_child_weight': 4, 'max_delta_step': 1, 'subsample': 0.7149154150920574}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:15,249] Trial 61 finished with value: 1.0 and parameters: {'learning_rate': 0.011862342732899368, 'max_depth': 10, 'n_estimators': 200, 'gamma': 1.2865440184919041e-08, 'min_child_weight': 7, 'max_delta_step': 10, 'subsample': 0.3189095853537025}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:16,286] Trial 62 finished with value: 1.0 and parameters: {'learning_rate': 0.01779381572152145, 'max_depth': 8, 'n_estimators': 200, 'gamma': 3.7534842591047454e-07, 'min_child_weight': 7, 'max_delta_step': 9, 'subsample': 0.215114338398245}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:17,297] Trial 63 finished with value: 1.0 and parameters: {'learning_rate': 0.0018387473009898166, 'max_depth': 8, 'n_estimators': 200, 'gamma': 1.8592719652866714e-08, 'min_child_weight': 6, 'max_delta_step': 5, 'subsample': 0.27971721620432}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:18,393] Trial 64 finished with value: 1.0 and parameters: {'learning_rate': 0.030807978055001347, 'max_depth': 6, 'n_estimators': 200, 'gamma': 3.6203390405291245e-08, 'min_child_weight': 8, 'max_delta_step': 8, 'subsample': 0.38860553650040536}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:19,744] Trial 65 finished with value: 1.0 and parameters: {'learning_rate': 0.007971405031406455, 'max_depth': 10, 'n_estimators': 200, 'gamma': 1.50733015236603e-07, 'min_child_weight': 6, 'max_delta_step': 9, 'subsample': 0.4986571007021438}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:20,348] Trial 66 finished with value: 1.0 and parameters: {'learning_rate': 0.08271802284632249, 'max_depth': 2, 'n_estimators': 300, 'gamma': 0.03604897587804746, 'min_child_weight': 5, 'max_delta_step': 8, 'subsample': 0.24797041693851568}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:21,329] Trial 67 finished with value: 1.0 and parameters: {'learning_rate': 0.047074254384835416, 'max_depth': 8, 'n_estimators': 200, 'gamma': 0.26673015131575833, 'min_child_weight': 8, 'max_delta_step': 3, 'subsample': 0.48549724955757445}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:21,888] Trial 68 finished with value: 1.0 and parameters: {'learning_rate': 0.0027393319115546055, 'max_depth': 6, 'n_estimators': 100, 'gamma': 5.729905085679466e-07, 'min_child_weight': 9, 'max_delta_step': 0, 'subsample': 0.3420990199972978}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:23,459] Trial 69 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 6.369228395663633e-05, 'max_depth': 6, 'n_estimators': 300, 'gamma': 0.176974045165128, 'min_child_weight': 7, 'max_delta_step': 6, 'subsample': 0.556151050357502}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:24,486] Trial 70 finished with value: 1.0 and parameters: {'learning_rate': 0.004069747492230676, 'max_depth': 4, 'n_estimators': 200, 'gamma': 0.000644888949608931, 'min_child_weight': 3, 'max_delta_step': 7, 'subsample': 0.588515954690182}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:25,354] Trial 71 finished with value: 1.0 and parameters: {'learning_rate': 0.054981046984031945, 'max_depth': 2, 'n_estimators': 200, 'gamma': 0.004837135760896544, 'min_child_weight': 7, 'max_delta_step': 8, 'subsample': 0.9951364849914757}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:26,390] Trial 72 finished with value: 1.0 and parameters: {'learning_rate': 0.025960526201471813, 'max_depth': 4, 'n_estimators': 200, 'gamma': 0.007501342042799601, 'min_child_weight': 6, 'max_delta_step': 9, 'subsample': 0.8689128795983238}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:27,354] Trial 73 finished with value: 1.0 and parameters: {'learning_rate': 0.037606217718789976, 'max_depth': 2, 'n_estimators': 200, 'gamma': 5.438048050257254e-05, 'min_child_weight': 8, 'max_delta_step': 10, 'subsample': 0.43988069495261933}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:28,048] Trial 74 finished with value: 1.0 and parameters: {'learning_rate': 0.07946096716099536, 'max_depth': 6, 'n_estimators': 200, 'gamma': 0.027337406125975426, 'min_child_weight': 7, 'max_delta_step': 7, 'subsample': 0.7876891073308188}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:29,517] Trial 75 finished with value: 1.0 and parameters: {'learning_rate': 0.010627268309641332, 'max_depth': 4, 'n_estimators': 300, 'gamma': 0.05703969758215362, 'min_child_weight': 4, 'max_delta_step': 9, 'subsample': 0.7587685541642031}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:30,539] Trial 76 finished with value: 1.0 and parameters: {'learning_rate': 0.015104995311994595, 'max_depth': 2, 'n_estimators': 200, 'gamma': 0.012082362761552628, 'min_child_weight': 2, 'max_delta_step': 0, 'subsample': 0.6340717272132245}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:31,487] Trial 77 finished with value: 1.0 and parameters: {'learning_rate': 0.006295368914792677, 'max_depth': 6, 'n_estimators': 200, 'gamma': 0.1120329678051589, 'min_child_weight': 10, 'max_delta_step': 8, 'subsample': 0.515636625890467}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:32,644] Trial 78 finished with value: 1.0 and parameters: {'learning_rate': 0.0480297820406428, 'max_depth': 8, 'n_estimators': 300, 'gamma': 0.0002235171042356535, 'min_child_weight': 5, 'max_delta_step': 1, 'subsample': 0.3052001031789404}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:33,316] Trial 79 finished with value: 1.0 and parameters: {'learning_rate': 0.09383870132836804, 'max_depth': 10, 'n_estimators': 200, 'gamma': 0.0029031654265013127, 'min_child_weight': 3, 'max_delta_step': 0, 'subsample': 0.932937417597139}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# ...
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:58,455] Trial 103 finished with value: 1.0 and parameters: {'learning_rate': 0.0029701927415301302, 'max_depth': 2, 'n_estimators': 100, 'gamma': 0.1842208057598947, 'min_child_weight': 6, 'max_delta_step': 3, 'subsample': 0.7706480578493834}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:59,045] Trial 104 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.0006847284486555727, 'max_depth': 2, 'n_estimators': 100, 'gamma': 1.0422611867689729e-08, 'min_child_weight': 6, 'max_delta_step': 3, 'subsample': 0.5981322591305783}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:29:59,604] Trial 105 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.0013089767093587697, 'max_depth': 2, 'n_estimators': 100, 'gamma': 0.3696472149966885, 'min_child_weight': 5, 'max_delta_step': 4, 'subsample': 0.38133286787013476}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:30:00,531] Trial 106 finished with value: 1.0 and parameters: {'learning_rate': 0.05220501582934737, 'max_depth': 4, 'n_estimators': 300, 'gamma': 0.808969476931378, 'min_child_weight': 8, 'max_delta_step': 4, 'subsample': 0.3013658652233989}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:30:01,119] Trial 107 finished with value: 1.0 and parameters: {'learning_rate': 0.020562832800717374, 'max_depth': 10, 'n_estimators': 100, 'gamma': 0.028665808100616256, 'min_child_weight': 7, 'max_delta_step': 2, 'subsample': 0.26161460405927933}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:30:01,918] Trial 108 finished with value: 1.0 and parameters: {'learning_rate': 0.09673353640366705, 'max_depth': 6, 'n_estimators': 200, 'gamma': 0.015806694020079917, 'min_child_weight': 7, 'max_delta_step': 1, 'subsample': 0.4299154832656116}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:30:03,539] Trial 109 finished with value: 1.0 and parameters: {'learning_rate': 0.006813804413252155, 'max_depth': 2, 'n_estimators': 300, 'gamma': 0.13227266891783004, 'min_child_weight': 2, 'max_delta_step': 5, 'subsample': 0.6173248203418026}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:30:04,623] Trial 110 finished with value: 1.0 and parameters: {'learning_rate': 0.001662444657124059, 'max_depth': 8, 'n_estimators': 200, 'gamma': 5.515693979613527e-06, 'min_child_weight': 4, 'max_delta_step': 3, 'subsample': 0.4633429943956686}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:30:05,656] Trial 111 finished with value: 1.0 and parameters: {'learning_rate': 0.0020825141427324597, 'max_depth': 8, 'n_estimators': 200, 'gamma': 0.0013447310484687683, 'min_child_weight': 8, 'max_delta_step': 7, 'subsample': 0.8070892898215938}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:30:06,750] Trial 112 finished with value: 1.0 and parameters: {'learning_rate': 0.001400615193504711, 'max_depth': 8, 'n_estimators': 200, 'gamma': 0.000237988224841742, 'min_child_weight': 8, 'max_delta_step': 2, 'subsample': 0.6363907511408445}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:30:07,790] Trial 113 finished with value: 1.0 and parameters: {'learning_rate': 0.0706144744202928, 'max_depth': 8, 'n_estimators': 200, 'gamma': 0.003247162560502884, 'min_child_weight': 9, 'max_delta_step': 6, 'subsample': 0.8332061193968453}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-10-06 23:30:08,865] Trial 114 finished with value: 0.6341333333333333 and parameters: {'learning_rate': 0.0008129480998722476, 'max_depth': 8, 'n_estimators': 200, 'gamma': 0.0756125117865405, 'min_child_weight': 7, 'max_delta_step': 7, 'subsample': 0.7880440643255884}. Best is trial 2 with value: 1.0.
# /Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [W 2024-10-06 23:30:09,922] Trial 115 failed with parameters: {'learning_rate': 0.004606324929686434, 'max_depth': 6, 'n_estimators': 200, 'gamma': 0.004659736809421895, 'min_child_weight': 8, 'max_delta_step': 9, 'subsample': 0.6970692167736915} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/optuna/study/_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/var/folders/2c/lb30d3ln1x79_hynq06_78cm0000gn/T/ipykernel_31364/2551086252.py", line 29, in objective
#     model.fit(x_train, y_train, eval_set=[(x_val, y_val)], early_stopping_rounds=10, verbose=False)
#   File "/Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/core.py", line 730, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py", line 1519, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/core.py", line 730, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/augielarson/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/core.py", line 2051, in update
#     _LIB.XGBoosterUpdateOneIter(
# KeyboardInterrupt
# [W 2024-10-06 23:30:09,935] Trial 115 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 43
#      40 if __name__ == "__main__":
#      41     # Creating a study to maximize accuracy
#      42     study = optuna.create_study(direction="maximize")
# ---> 43     study.optimize(objective, n_trials=1000, timeout=600)
#      45     # Output study results
#      46     print("Number of finished trials: ", len(study.trials))
#
# File ~/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/optuna/study/_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File ~/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/optuna/study/_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File ~/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/optuna/study/_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File ~/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/optuna/study/_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In[11], line 29, in objective(trial)
#      14 model = XGBClassifier(
#      15     objective='binary:logistic',
#      16     learning_rate=learning_rate,
#    (...)
#      25     eval_metric='logloss'  # To avoid warning for label encoding
#      26 )
#      28 # Train the model
# ---> 29 model.fit(x_train, y_train, eval_set=[(x_val, y_val)], early_stopping_rounds=10, verbose=False)
#      31 # Predict on validation set
#      32 y_pred = model.predict(x_val)
#
# File ~/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/sklearn.py:1519, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1491 (
#    1492     model,
#    1493     metric,
#    (...)
#    1498     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1499 )
#    1500 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1501     missing=self.missing,
#    1502     X=X,
#    (...)
#    1516     feature_types=self.feature_types,
#    1517 )
# -> 1519 self._Booster = train(
#    1520     params,
#    1521     train_dmatrix,
#    1522     self.get_num_boosting_rounds(),
#    1523     evals=evals,
#    1524     early_stopping_rounds=early_stopping_rounds,
#    1525     evals_result=evals_result,
#    1526     obj=obj,
#    1527     custom_metric=metric,
#    1528     verbose_eval=verbose,
#    1529     xgb_model=model,
#    1530     callbacks=callbacks,
#    1531 )
#    1533 if not callable(self.objective):
#    1534     self.objective = params["objective"]
#
# File ~/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/anaconda3/envs/CNNtest311/lib/python3.11/site-packages/xgboost/core.py:2051, in Booster.update(self, dtrain, iteration, fobj)
#    2047 self._assign_dmatrix_features(dtrain)
#    2049 if fobj is None:
#    2050     _check_call(
# -> 2051         _LIB.XGBoosterUpdateOneIter(
#    2052             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2053         )
#    2054     )
#    2055 else:
#    2056     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
